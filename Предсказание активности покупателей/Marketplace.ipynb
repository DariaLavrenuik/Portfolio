# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Общая-информация-по-проекту" data-toc-modified-id="Общая-информация-по-проекту-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Общая информация по проекту</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Цель:" data-toc-modified-id="Цель:-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Цель:</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Предварительный-план-работы:" data-toc-modified-id="Предварительный-план-работы:-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>Предварительный план работы:</a></span></li></ul></li></ul></li><li><span><a href="#Загрузка-и-ознакомление-с-данными" data-toc-modified-id="Загрузка-и-ознакомление-с-данными-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузка и ознакомление с данными</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Смена-типов-данных" data-toc-modified-id="Смена-типов-данных-2.0.0.1"><span class="toc-item-num">2.0.0.1&nbsp;&nbsp;</span>Смена типов данных</a></span></li><li><span><a href="#Проверка-дубликатов." data-toc-modified-id="Проверка-дубликатов.-2.0.0.2"><span class="toc-item-num">2.0.0.2&nbsp;&nbsp;</span>Проверка дубликатов.</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-2.0.0.3"><span class="toc-item-num">2.0.0.3&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-2.1.0.1"><span class="toc-item-num">2.1.0.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Отбор-и-генерация-признаков" data-toc-modified-id="Отбор-и-генерация-признаков-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Отбор и генерация признаков</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Добавим-целевой-признак-target" data-toc-modified-id="Добавим-целевой-признак-target-3.0.0.1"><span class="toc-item-num">3.0.0.1&nbsp;&nbsp;</span>Добавим целевой признак target</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.0.0.2"><span class="toc-item-num">3.0.0.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Кластеризация-признаков-с-помощью-k-means" data-toc-modified-id="Кластеризация-признаков-с-помощью-k-means-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Кластеризация признаков с помощью k-means</a></span></li><li><span><a href="#Модель-LGBM" data-toc-modified-id="Модель-LGBM-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>Модель LGBM</a></span></li><li><span><a href="#Обучение-HistGradientBoostingClassifier" data-toc-modified-id="Обучение-HistGradientBoostingClassifier-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>Обучение HistGradientBoostingClassifier</a></span></li><li><span><a href="#Обучение-Catboost" data-toc-modified-id="Обучение-Catboost-3.0.4"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>Обучение Catboost</a></span></li><li><span><a href="#Обучение-Random-forest-Classifier" data-toc-modified-id="Обучение-Random-forest-Classifier-3.0.5"><span class="toc-item-num">3.0.5&nbsp;&nbsp;</span>Обучение Random forest Classifier</a></span></li><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-3.0.6"><span class="toc-item-num">3.0.6&nbsp;&nbsp;</span>Сравнение моделей</a></span></li><li><span><a href="#Обучение-лучшей-модели" data-toc-modified-id="Обучение-лучшей-модели-3.0.7"><span class="toc-item-num">3.0.7&nbsp;&nbsp;</span>Обучение лучшей модели</a></span></li><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-3.0.8"><span class="toc-item-num">3.0.8&nbsp;&nbsp;</span>Выводы:</a></span></li></ul></li></ul></li><li><span><a href="#Общие-Выводы:" data-toc-modified-id="Общие-Выводы:-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Общие Выводы:</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#На-этапе-ознакомления-с-данными-были-проделаны-следующие-шаги:" data-toc-modified-id="На-этапе-ознакомления-с-данными-были-проделаны-следующие-шаги:-4.0.0.1"><span class="toc-item-num">4.0.0.1&nbsp;&nbsp;</span>На этапе ознакомления с данными были проделаны следующие шаги:</a></span></li><li><span><a href="#На-этапе-исследовательского-анализа-данных-были-сделаны-следующие-выводы:" data-toc-modified-id="На-этапе-исследовательского-анализа-данных-были-сделаны-следующие-выводы:-4.0.0.2"><span class="toc-item-num">4.0.0.2&nbsp;&nbsp;</span>На этапе исследовательского анализа данных были сделаны следующие выводы:</a></span></li><li><span><a href="#На-этапе-отбора-и-генерации-признаков-было-сделано--следующее:" data-toc-modified-id="На-этапе-отбора-и-генерации-признаков-было-сделано--следующее:-4.0.0.3"><span class="toc-item-num">4.0.0.3&nbsp;&nbsp;</span>На этапе отбора и генерации признаков было сделано  следующее:</a></span></li><li><span><a href="#На-этапе-обучения-моделей:" data-toc-modified-id="На-этапе-обучения-моделей:-4.0.0.4"><span class="toc-item-num">4.0.0.4&nbsp;&nbsp;</span>На этапе обучения моделей:</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Общая информация по проекту
#
# ### Цель:
# Создать решение для предсказания, совершит ли покупатель повторную покупку в течение ближайших 30 дней.
#
# ### Описание данных
#
# marketplace - мультикатегорийный магазин с посещаемостью более 8 млн сессий в месяц;
#
# apparel - магазин одежды, по характеристикам похожий на маркетплейс;
#
# gifts – магазин подарков, очень маленький;
#
# client_id – идентификатор клиента;
#
# quantity – количество товара в заказе;
#
# price – цена 1 единицы товара в заказе;
#
# message_id – идентификатор сообщения из рассылки;
#
# date – дата покупки;

# %% [markdown]
# ### Предварительный план работы:
# 🔸загрузка и ознакомление с данными,
#
# 🔸предварительная обработка и отбор полезных признаков,
#
# 🔸полноценный разведочный анализ,
#
# 🔸разработка новых синтетических признаков,
#
# 🔸отбор финального набора обучающих признаков,
#
# 🔸выбор и обучение моделей,
#
# 🔸итоговая оценка качества предсказания лучшей модели,
#
# 🔸анализ важности ее признаков
#
# 🔸подготовка отчета по исследованию

# %% [markdown]
# # Загрузка и ознакомление с данными

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score, auc, confusion_matrix
from sklearn import metrics
from sklearn.cluster import KMeans
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
apparel = pd.read_csv('apparel-purchases.csv')
gifts = pd.read_csv('gifts-purchases.csv')
marketplace = pd.read_csv('marketplace-purchases.csv')

# %%
apparel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133104 entries, 0 to 133103
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   client_id       133104 non-null  int64
#  1   quantity        133104 non-null  int64
#  2   price           133104 non-null  float64
#  3   date            133104 non-null  object
#  4   message_id      133104 non-null  object
#  5   recommended_by  133104 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 6.1+ MB

# %%
apparel.head()
# Out:
#              client_id  quantity   price        date  \
# 0  1515915625468068833         1  3499.0  2023-09-08
# 1  1515915625468068833         1  3499.0  2023-09-08
# 2  1515915625468068833         1  3499.0  2023-09-08
# 3  1515915625468068833         1  2450.0  2023-09-08
# 4  1515915625468068833         1  2450.0  2023-09-08
#
#                                 message_id recommended_by
# 0  1515915625468068833-13781-64fad81bece56   bulk_message
# 1  1515915625468068833-13781-64fad81bece56   bulk_message
# 2  1515915625468068833-13781-64fad81bece56   bulk_message
# 3  1515915625468068833-13781-64fad81bece56   bulk_message
# 4  1515915625468068833-13781-64fad81bece56   bulk_message

# %%
gifts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811 entries, 0 to 810
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   client_id       811 non-null    int64
#  1   quantity        811 non-null    int64
#  2   price           811 non-null    float64
#  3   date            811 non-null    object
#  4   message_id      811 non-null    object
#  5   recommended_by  811 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 38.1+ KB

# %%
gifts.head()
# Out:
#              client_id  quantity    price        date  \
# 0  1515915625803894158         1   8943.0  2023-10-11
# 1  1515915625803894158         1  46369.0  2023-10-11
# 2  1515915625803894158         1   4666.0  2023-10-11
# 3  1515915625803894158         1  11963.0  2023-10-11
# 4  1515915625803894158         1  13107.0  2023-10-11
#
#                                 message_id recommended_by
# 0  1515915625935652010-16166-6525589bca68f   bulk_message
# 1  1515915625935652010-16166-6525589bca68f   bulk_message
# 2  1515915625935652010-16166-6525589bca68f   bulk_message
# 3  1515915625935652010-16166-6525589bca68f   bulk_message
# 4  1515915625935652010-16166-6525589bca68f   bulk_message

# %%
marketplace.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48182 entries, 0 to 48181
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   client_id   48182 non-null  int64
#  1   quantity    48182 non-null  int64
#  2   price       48182 non-null  float64
#  3   message_id  48182 non-null  object
#  4   created_at  48182 non-null  object
#  5   date        48182 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 2.2+ MB

# %%
marketplace.head()
# Out:
#              client_id  quantity    price  \
# 0  1515915625440944408         1   6298.0
# 1  1515915625440992498         1   7318.0
# 2  1515915625441026424         1  65798.0
# 3  1515915625441118180         1   5598.0
# 4  1515915625441124500         1  77998.0
#
#                                message_id  created_at                 date
# 0  1515915625440944408-1752-6450b79616277  2023-05-02  2023-05-02 08:49:57
# 1  1515915625440992498-1818-646b35d089c98  2023-05-22  2023-05-22 13:52:13
# 2  1515915625441026424-1802-64634e24a2cb9  2023-05-17  2023-05-17 11:21:04
# 3  1515915625441118180-1820-646c9444ebf39  2023-05-23  2023-05-23 19:02:53
# 4  1515915625441124500-1825-646ed5cf4d5ed  2023-05-25  2023-05-25 07:46:52

# %% [markdown]
# Добавим для каждой таблицы признак с ее названием, чтобы в дальнейшем анализировать данные о каждом магазине отдельно.

# %%
marketplace['shop_name']= 'marketplace'
gifts['shop_name']= 'gifts'
apparel['shop_name']='apparel'

# %% [markdown]
# Для удобства объединим все таблицы в одну.

# %%
data = pd.concat([apparel,gifts,marketplace], sort=False, axis=0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182097 entries, 0 to 48181
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   client_id       182097 non-null  int64
#  1   quantity        182097 non-null  int64
#  2   price           182097 non-null  float64
#  3   date            182097 non-null  object
#  4   message_id      182097 non-null  object
#  5   recommended_by  133915 non-null  object
#  6   shop_name       182097 non-null  object
#  7   created_at      48182 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 12.5+ MB

# %%
data.head()
# Out:
#              client_id  quantity   price        date  \
# 0  1515915625468068833         1  3499.0  2023-09-08
# 1  1515915625468068833         1  3499.0  2023-09-08
# 2  1515915625468068833         1  3499.0  2023-09-08
# 3  1515915625468068833         1  2450.0  2023-09-08
# 4  1515915625468068833         1  2450.0  2023-09-08
#
#                                 message_id recommended_by shop_name created_at
# 0  1515915625468068833-13781-64fad81bece56   bulk_message   apparel        NaN
# 1  1515915625468068833-13781-64fad81bece56   bulk_message   apparel        NaN
# 2  1515915625468068833-13781-64fad81bece56   bulk_message   apparel        NaN
# 3  1515915625468068833-13781-64fad81bece56   bulk_message   apparel        NaN
# 4  1515915625468068833-13781-64fad81bece56   bulk_message   apparel        NaN

# %% [markdown]
# #### Смена типов данных

# %% [markdown]
# Приведем данные со временем к формату datetime

# %%
data['date_new'] = pd.to_datetime(data['date']).dt.date
data['created_at']= pd.to_datetime(data['created_at'])
data['date'] = pd.to_datetime(data['date'], format='%Y-%m-%d')

# %%
missing_values = data.isna().sum()
for column, count in zip(missing_values.index, missing_values):
    percentage = (count / len(data)) * 100
    print(f"{column}: {count} ({percentage:.2f}%)")
# Out:
# client_id: 0 (0.00%)
# quantity: 0 (0.00%)
# price: 0 (0.00%)
# date: 0 (0.00%)
# message_id: 0 (0.00%)
# recommended_by: 48182 (26.46%)
# shop_name: 0 (0.00%)
# created_at: 133915 (73.54%)
# date_new: 0 (0.00%)

# %% [markdown]
# У нас есть данные в прзнаке created_at только для клиентов marketplace. Отсюда пропуски.

# %% [markdown]
# #### Проверка дубликатов.

# %%
'Количество дубликатов в базе:',data.duplicated().sum()
# Out:
# ('Количество дубликатов в базе:', 61465)

# %%
data[data.duplicated()==True]
# Out:
#                  client_id  quantity    price                date  \
# 1      1515915625468068833         1   3499.0 2023-09-08 00:00:00
# 2      1515915625468068833         1   3499.0 2023-09-08 00:00:00
# 4      1515915625468068833         1   2450.0 2023-09-08 00:00:00
# 5      1515915625468068833         1   2450.0 2023-09-08 00:00:00
# 10     1515915625468079941         1   1499.0 2023-09-01 00:00:00
# ...                    ...       ...      ...                 ...
# 48020  1515915625574498083         1      2.0 2023-04-13 13:52:34
# 48051  1515915625574682759         1   1598.0 2023-04-24 09:57:07
# 48129  1515915625575372709         1      2.0 2023-04-25 23:52:16
# 48138  1515915625575436521         1  59998.0 2023-04-24 08:30:19
# 48178  1515915625575803144         1  29998.0 2023-04-29 11:19:29
#
#                                     message_id recommended_by    shop_name  \
# 1      1515915625468068833-13781-64fad81bece56   bulk_message      apparel
# ...

# %% [markdown]
# В данных каждая единица товара записана в отдельную покупку. Не будем удалять дубликаты, чтобы не искажать поведение пользователей.

# %% [markdown]
# #### Вывод:
#
# На этапе ознакомления с данными были проделаны следующие шаги:
#
# - загрузка данных
# - объединение данных в одну таблицу
# - изменение итпов данных
# - поверка на наличие дубликатов. Обнаруженные дубликаты мы не удаляли, считая, что это разные товары, приобретенные в одно время

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Посмотрим на данные о пользователях

# %%
print('Общее кличество уникальных пользователей на сайтах:',len(data['client_id'].unique()))
print('Количество уникальных клиентов в marketplace:',len(data[data['shop_name'] =='marketplace']['client_id'].unique()))
print('Количество уникальных клиентов в gifts:',len(data[data['shop_name'] =='gifts']['client_id'].unique()))
print('Количество уникальных клиентов в apparel:',len(data[data['shop_name'] =='apparel']['client_id'].unique()))
# Out:
# Общее кличество уникальных пользователей на сайтах: 47004
# Количество уникальных клиентов в marketplace: 17787
# Количество уникальных клиентов в gifts: 326
# Количество уникальных клиентов в apparel: 28891

# %% [markdown]
# Посмотрим на данные о количестве товаров за одну покупку.

# %%
data['quantity'].value_counts()
# Out:
# 1     181466
# 2        437
# 3        107
# 4         25
# 5         13
# 6         11
# 10        10
# 7          7
# 8          4
# 50         4
# 9          3
# 15         3
# 20         2
# 30         2
# 18         1
# 27         1
# 23         1
# Name: quantity, dtype: int64

# %% [markdown]
# В наших данных, кроме некоторых выбросов, в каждой отдельной записи только одна единица товара. Чтобы оценить общее количество товаров за одну покупку, будем считать все покупки, совершенные пользователем за день как один заказ. Добавим это значение в новую колонку.

# %%
data.groupby(['client_id','date'])['quantity'].count()
# Out:
# client_id            date
# 1515915625440099873  2023-07-16 08:25:31    1
#                      2023-08-09 08:59:08    1
# 1515915625440939402  2023-01-30 13:13:37    1
# 1515915625440944408  2023-03-01 10:21:12    1
#                      2023-05-02 08:49:57    1
#                                            ..
# 1515915626005014483  2023-09-13 00:00:00    1
# 1515915626010039507  2023-10-02 00:00:00    2
# 1515915626011484905  2023-10-13 00:00:00    5
# 1515915626012131867  2023-09-12 00:00:00    1
# 1515915626013602677  2023-10-11 00:00:00    3
# Name: quantity, Length: 65576, dtype: int64

# %%
data['quantity_count'] = data.groupby(['client_id', 'date'])['quantity'].transform('count')

# %%
data['quantity_count'].describe()
# Out:
# count    182097.000000
# mean          7.469903
# std          12.591927
# min           1.000000
# 25%           2.000000
# 50%           4.000000
# 75%           8.000000
# max         216.000000
# Name: quantity_count, dtype: float64

# %%
data.groupby('shop_name')['quantity_count'].describe()
# Out:
#                 count      mean        std  min  25%  50%   75%    max
# shop_name
# apparel      133104.0  9.299630  14.132389  1.0  3.0  6.0  10.0  216.0
# gifts           811.0  4.632552   4.559416  1.0  2.0  3.0   6.0   22.0
# marketplace   48182.0  2.462994   3.563242  1.0  1.0  2.0   3.0   48.0

# %%
# Создаем общую фигуру и оси для всех боксплотов
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

# Боксплот для всех магазинов
data.boxplot('quantity_count', ax=axes[0, 0])
axes[0, 0].set_ylim(-5, 30)
axes[0, 0].set_title('Количество товаров за одну покупку по всем магазинам')

# Боксплот для магазина 'marketplace'
data[data['shop_name'] == 'marketplace'].boxplot('quantity_count', ax=axes[0, 1])
axes[0, 1].set_ylim(-5, 30)
axes[0, 1].set_title('Количество товаров за одну покупку в marketplace')

# Боксплот для магазина 'apparel'
data[data['shop_name'] == 'apparel'].boxplot('quantity_count', ax=axes[1, 0])
axes[1, 0].set_ylim(-5, 30)
axes[1, 0].set_title('Количество товаров за одну покупку в apparel')

# Боксплот для магазина 'gifts'
data[data['shop_name'] == 'gifts'].boxplot('quantity_count', ax=axes[1, 1])
axes[1, 1].set_ylim(-5, 30)
axes[1, 1].set_title('Количество товаров за одну покупку в gifts')

# Добавляем разметку
plt.tight_layout()
plt.show()

# %%
data[data['quantity_count'] ==216]
# Out:
#                   client_id  quantity  price       date  \
# 110420  1515915625624308268         1   70.0 2022-11-11
# 110421  1515915625624308268         1   70.0 2022-11-11
# 110422  1515915625624308268         1   69.0 2022-11-11
# 110423  1515915625624308268         1   69.0 2022-11-11
# 110424  1515915625624308268         1   69.0 2022-11-11
# ...                     ...       ...    ...        ...
# 110631  1515915625624308268         1  139.0 2022-11-11
# 110632  1515915625624308268         1  139.0 2022-11-11
# 110633  1515915625624308268         1  139.0 2022-11-11
# 110634  1515915625624308268         1  104.0 2022-11-11
# 110635  1515915625624308268         1  104.0 2022-11-11
#
#                                     message_id recommended_by shop_name  \
# 110420  1515915625624308268-7803-636dfea7ca890   bulk_message   apparel
# 110421  1515915625624308268-7803-636dfea7ca890   bulk_message   apparel
# 110422  1515915625624308268-7803-636dfea7ca890   bulk_message   apparel
# ...

# %% [markdown]
# Среднее количесво товаров в одном чеке по всем магазинам - 7.4 Самое высокое значение в apparel - 9.2, затем gifts - 4.6, наименьшее в marketplace - 2.4.
#
# В данных есть выбросы, самое больше количесвто товаров в одном чеке в apparel - 216. Проверили эти данные вручную. В этом заказе очень низкая цена товаров - 70, 139 рублей. Можно предположить, что это оптовая закупка, не будем удалять эти выбросы, чтобы не искажать поведение пользователей.

# %% [markdown]
# Посмотрим на данные о цене.

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(10, 10))

# Боксплот и гистограмма для магазина 'marketplace'
data[data['shop_name'] == 'marketplace'].boxplot('price', ax=axes[0,0])
axes[0,0].set_title('Боксплот цен в marketplace')

data[data['shop_name'] == 'marketplace']['price'].hist(bins=50, ax=axes[0,1])
axes[0,1].set_xlim(-10000, 400000)
axes[0,1].set_title('Гистограмма цен в marketplace')

# Боксплот и гистограмма для магазина 'apparel'
data[data['shop_name'] == 'apparel'].boxplot('price', ax=axes[1,0])
axes[1,0].set_title('Боксплот цен в apparel')
axes[1,0].set_ylim(-100, 40000)

data[data['shop_name'] == 'apparel']['price'].hist(bins=50, ax=axes[1,1])
axes[1,1].set_xlim(-100, 30000)
axes[1,1].set_title('Гистограмма цен в apparel')

# Боксплот и гистограмма для магазина 'gifts'

data[data['shop_name'] == 'gifts'].boxplot('price', ax=axes[2,0])
axes[2,0].set_title('Боксплот цен в gifts')

data[data['shop_name'] == 'gifts']['price'].hist(bins=50, ax=axes[2,1])
axes[2,1].set_title('Гистограмма цен в gifts')

data.boxplot('price', ax=axes[3,0])
axes[3,0].set_title('Боксплот цен во всех магазинах')

data['price'].hist(bins=50, ax=axes[3,1])
axes[3,1].set_title('Гистограмма цен во всех магазинах')
axes[3,1].set_xlim(-10000, 400000)

plt.tight_layout()  # автоматическое распределение между подграфиками
plt.show()

# %%
data.groupby('shop_name')['price'].describe()
# Out:
#                 count          mean           std    min      25%     50%  \
# shop_name
# apparel      133104.0   1110.433067   1257.080854    1.0   280.00   799.0
# gifts           811.0  14468.795314  17774.341837  656.0  3878.00  7533.0
# marketplace   48182.0  27918.953157  44922.741767    0.0  1204.25  9998.0
#
#                  75%        max
# shop_name
# apparel       1499.0    63499.0
# gifts        17938.0   173586.0
# marketplace  35998.0  1299998.0

# %%
data['price'].describe()
# Out:
# count    1.820970e+05
# mean     8.263334e+03
# std      2.600605e+04
# min      0.000000e+00
# 25%      3.370000e+02
# 50%      1.049000e+03
# 75%      2.499000e+03
# max      1.299998e+06
# Name: price, dtype: float64

# %% [markdown]
# Самая высокая средняя стоимость 1 единицы товара в заказе в магазине marketplace - 27'918, значительно ниже у gifts - 14'468, самый низкий в apparel - 1'110. Средний чек по всем магазинам - 8'263.

# %% [markdown]
# Проанализируем так же распределение общей стоимости всех товаров в чеке. Для этого добавим колонку с общей суммой всех заказов за день.

# %%
data['total_price']=data.groupby(['client_id','date'])['price'].transform('sum')

# %%
data.groupby('shop_name')['total_price'].describe()
# Out:
#                 count          mean            std    min      25%      50%  \
# shop_name
# apparel      133104.0   7467.159657   10583.816632    1.0   2098.0   4318.0
# gifts           811.0  69138.658446   94728.726001  669.0  11708.0  29016.0
# marketplace   48182.0  56216.692084  101708.172307    0.0   5998.0  27993.0
#
#                  75%        max
# shop_name
# apparel       8729.0   160955.0
# gifts        82884.0   394556.0
# marketplace  76995.0  1812248.0

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(10, 10))

# Боксплот и гистограмма для магазина 'marketplace'
data[data['shop_name'] == 'marketplace'].boxplot('total_price', ax=axes[0,0])
axes[0,0].set_title('Боксплот цен в marketplace')

data[data['shop_name'] == 'marketplace']['total_price'].hist(bins=50, ax=axes[0,1])
axes[0,1].set_xlim(-10000, 400000)
axes[0,1].set_title('Гистограмма цен в marketplace')
axes[0,1].tick_params(axis='x', rotation=45) 

# Боксплот и гистограмма для магазина 'apparel'
data[data['shop_name'] == 'apparel'].boxplot('total_price', ax=axes[1,0])
axes[1,0].set_title('Боксплот цен в apparel')
axes[1,0].set_ylim(-100, 40000)

data[data['shop_name'] == 'apparel']['total_price'].hist(bins=50, ax=axes[1,1])
axes[1,1].set_xlim(-100, 30000)
axes[1,1].set_title('Гистограмма цен в apparel')

# Боксплот и гистограмма для магазина 'gifts'

data[data['shop_name'] == 'gifts'].boxplot('total_price', ax=axes[2,0])
axes[2,0].set_title('Боксплот цен в gifts')

data[data['shop_name'] == 'gifts']['total_price'].hist(bins=50, ax=axes[2,1])
axes[2,1].set_title('Гистограмма цен в gifts')
axes[2,1].tick_params(axis='x', rotation=45) 

data.boxplot('total_price', ax=axes[3,0])
axes[3,0].set_title('Боксплот цен во всех магазинах')

data['total_price'].hist(bins=50, ax=axes[3,1])
axes[3,1].set_title('Гистограмма цен во всех магазинах')
axes[3,1].set_xlim(-10000, 400000)
axes[3,1].tick_params(axis='x', rotation=45) 

plt.tight_layout()  # автоматическое распределение между подграфиками
plt.show()

# %% [markdown]
# Средняя стоимость чека в apparel - 7'467 р, в gifts - 69'138 р, в marketplace - 56'216 р.
# Гистограммы со скошенным вправо распределением, из-за того, что цены не бывают отрицательными. Распределения отдельно взятых магазинов выглядит нормальным, однако данные в объединенной таблице сконцентрированы у низких значений.
# Во всех графиках есть выбросы с высокими ценами на товар - 1'812'248 р, 394'556 р, 160'955 р. Выбросы объясняются разными видами товаров на торгровых площадках и выглядят нормально.

# %% [markdown]
# Проанализируем данные о времени.

# %%
print('Вся база:')
print('С',data['date'].min(),'до', data['date'].max() )
print('Для apparel:')
print('С',data[data['shop_name']=='apparel']['date'].min(),'до', data[data['shop_name']=='apparel']['date'].max())
print('Для marketplace:')
print('С',data[data['shop_name']=='marketplace']['date'].min(),'до', data[data['shop_name']=='marketplace']['date'].max())
print('Для gifts:')
print('С',data[data['shop_name']=='gifts']['date'].min(),'до', data[data['shop_name']=='gifts']['date'].max())
# Out:
# Вся база:
# С 2022-10-26 00:00:00 до 2023-10-26 13:34:11
# Для apparel:
# С 2022-10-26 00:00:00 до 2023-10-26 00:00:00
# Для marketplace:
# С 2022-10-26 08:35:46 до 2023-10-26 13:34:11
# Для gifts:
# С 2022-10-26 00:00:00 до 2023-10-24 00:00:00

# %% [markdown]
# Видим одинаковый временной промежуток для всех магазинов длинной в год.
# Создадим дополнительный признак с месяцем продажи и посмотрим, меняется ли поведение покупателей в течение года.

# %%
data['month'] =data['date'].dt.month

# %%
month_price = data.groupby(['shop_name', 'month'])['price'].sum().reset_index()
gifts = month_price[month_price['shop_name']=='gifts']
apparel = month_price[month_price['shop_name']=='apparel']
marketplace = month_price[month_price['shop_name']=='marketplace']

# графики для gifts
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(10, 10))


axes[0,0].bar(gifts['month'], gifts['price'])
axes[0,0].set_title('gifts')
axes[0,0].set_xlabel('месяц')
axes[0,0].set_ylabel('прибыль')

axes[0,1].plot(gifts['month'], gifts['price'])

# графики для apparel
axes[1,0].bar(apparel['month'], apparel['price'])
axes[1,0].set_title('apparel')
axes[1,0].set_xlabel('месяц')
axes[1,0].set_ylabel('прибыль')

axes[1,1].plot(apparel['month'], apparel['price'])

# графики для marketplace
axes[2,0].bar(marketplace['month'], marketplace['price'])
axes[2,0].set_title('marketplace')
axes[2,0].set_xlabel('месяц')
axes[2,0].set_ylabel('прибыль')

axes[2,1].plot(marketplace['month'], marketplace['price'])

plt.tight_layout()
plt.show()

# %% [markdown]
# Поведение клиентов во всех трех магазинах существенно отличается.В магазине marketplace пик продаж в феврале, минимум в августе. В gifts пик продаж в июне и июле, спад  в апреле и декабре. В apparel пик в ноябре-декабре, падение в январе, феврале. Самые стабильные продажи в marketplace, наибольшие падения у apparel.

# %% [markdown]
# #### Вывод:
#
# На этапе исследовательского анализа данных были сделаны следующие выводы:
#
# Общее кличество уникальных пользователей на сайтах: 47004
#
# Количество уникальных клиентов в marketplace: 17787
# Количество уникальных клиентов в gifts: 326
#
# Количество уникальных клиентов в apparel: 28891
#
# Среднее количесво товаров в одном чеке по всем магазинам - 7.4 Самое высокое значение в apparel - 9.2, затем gifts - 4.6, наименьшее в marketplace - 2.4.
#
# В данных есть выбросы, самое больше количество товаров в одном чеке в apparel - 216. Проверили эти данные вручную. В этом заказе очень низкая цена товаров - 70, 139 рублей. Можно предположить, что это оптовая закупка, не будем удалять эти выбросы, чтобы не искажать поведение пользователей.
#
# Самая высокая средняя стоимость 1 единицы товара в заказе в магазине marketplace - 27'918, значительно ниже у gifts - 14'468, самый низкий в apparel - 1'110. Средний чек по всем магазинам - 8'263.
#
# Средняя стоимость чека в apparel - 7'467, в gifts - 69'138, в marketplace - 56'216.
#
# У нас есть данные за одинаковый временной промежуток для всех магазинов длинной в год. Создали дополнительный признак с месяцем продажи и посмотрели, меняется ли поведение покупателей в течение года. Поведение клиентов во всех трех магазинах существенно отличается.В магазине marketplace пик продаж в феврале, минимум в августе. В gifts пик продаж в июне и июле, спад в апреле и декабре. В apparel пик в ноябре-декабре, падение в январе, феврале. Самые стабильные продажи в marketplace, наибольшие падения у apparel.

# %% [markdown]
# # Отбор и генерация признаков

# %% [markdown]
# #### Добавим целевой признак target

# %%
data.sort_values(by='date', inplace=True, ascending=False)

# %%
date_end = pd.Timestamp('2023-9-26')
positive_class=data[data['date_new'] >= date_end]
# Out:
# C:\Users\frolo\AppData\Local\Temp\ipykernel_20504\3952939868.py:2: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   positive_class=data[data['date_new'] >= date_end]

# %%
data=data[data['date_new'] < date_end]
# Out:
# C:\Users\frolo\AppData\Local\Temp\ipykernel_20504\1142181771.py:1: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   data=data[data['date_new'] < date_end]

# %%
client_1 =list(positive_class['client_id'].unique())
client_1_set = set(client_1)

# %%
data.head()
# Out:
#                  client_id  quantity    price                date  \
# 26356  1515915625586262931         1  19998.0 2023-09-25 22:29:03
# 16670  1515915625540672812         1   2578.0 2023-09-25 20:14:00
# 14481  1515915625529302531         1  65798.0 2023-09-25 19:42:09
# 945    1515915625444043152         1  65798.0 2023-09-25 19:42:09
# 20097  1515915625553447912         1   4398.0 2023-09-25 19:00:12
#
#                                    message_id recommended_by    shop_name  \
# 26356  1515915625568477918-2119-650fd137afb7a            NaN  marketplace
# 16670  1515915625540672812-2119-650fd1308b570            NaN  marketplace
# 14481  1515915625529302531-2120-65111a0a61c35            NaN  marketplace
# 945    1515915625529302531-2120-65111a0a61c35            NaN  marketplace
# 20097  1515915625553447912-1775-645b656f2cafe            NaN  marketplace
#
#       created_at    date_new  quantity_count  total_price  month
# ...

# %%
data['time_diff'] =data.groupby('client_id')['date_new'].transform('diff')

# %%
aggregations = {
          
    'total_price': ['mean', 'max', 'min'],        
     'date_new':['max', 'min'],   
     'quantity_count':'mean',
    'price':['mean', 'max', 'min'],
    'time_diff':['mean', 'min', 'max' ]
}

# Perform the aggregations
aggregated_data = data.groupby('client_id').agg(aggregations)
aggregated_data.reset_index(inplace=True)

# %%
renamed_columns = {
    ('total_price', 'mean'): 'average_total_price',
    ('total_price', 'max'): 'max_total_price',
    ('total_price', 'min'): 'min_total_price',
    ('date_new', 'max'): 'max_date_new',
    ('date_new', 'min'): 'min_date_new',
    ('quantity_count', 'mean'): 'average_quantity_count',
    ('price', 'mean'): 'average_price',
    ('price', 'max'): 'max_price',
    ('price', 'min'): 'min_price',
    ('time_diff', 'mean'): 'average_time_diff',
    ('time_diff', 'min'): 'min_time_diff',
    ('time_diff', 'max'): 'max_time_diff',
}

aggregated_data.columns =['client_id'] + [renamed_columns[col] for col in aggregated_data.columns[1:]]

# %%
aggregated_data
# Out:
#                  client_id  average_total_price  max_total_price  \
# 0      1515915625440099873         16608.000000          31998.0
# 1      1515915625440939402         75998.000000          75998.0
# 2      1515915625440944408         27059.333333          73998.0
# 3      1515915625440947454          2243.000000           4284.0
# 4      1515915625440952940           479.000000            479.0
# ...                    ...                  ...              ...
# 44614  1515915625996380624         70251.000000          70251.0
# 44615  1515915625997511191         15043.000000          15043.0
# 44616  1515915625997770678        104177.000000         104177.0
# 44617  1515915626005014483          7534.000000           7534.0
# 44618  1515915626012131867         25834.000000          25834.0
#
#        min_total_price max_date_new min_date_new  average_quantity_count  \
# 0               1218.0   2023-08-09   2023-07-16                     1.0
# ...

# %% [markdown]
# Добавим целевую метрику

# %%
aggregated_data['target'] = aggregated_data['client_id'].apply(lambda x: 1 if x in client_1_set else 0)

# %% [markdown]
# Подготовим данные

# %%
features=aggregated_data.drop(['target', 'client_id'], axis=1)
target=aggregated_data['target']

# %%
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    stratify=target, 
                                                    random_satate=1234)

# %% [markdown]
# #### Вывод
# На этапе отбора и генерации признаков было сделано  следующее:
#
# Добавлена целевая метрика
#
# Была применена агрегация по уникальным пользователям и созданы следующие синтетические признаки:
# - average_total_price	max_
# - total_price
# - min_total_price
# - max_date_new
# - min_date_new
# - average_quantity_count
# - average_price
# - max_price
# - min_price
# - average_time_diff
# - min_time_diff
# - max_time_diff

# %% [markdown]
# ### Кластеризация признаков с помощью k-means

# %% [markdown]
# Подготовим признаки для модели k-means

# %%
x_train_k=x_train.copy()

x_train_k['average_time_diff_num']=x_train_k['average_time_diff'] / pd.Timedelta(days=1)
x_train_k['min_time_diff_num']=x_train_k['min_time_diff'] / pd.Timedelta(days=1)
x_train_k['max_time_diff_num']=x_train_k['max_time_diff'] / pd.Timedelta(days=1)
x_train_k['days']=(x_train_k['max_date_new']-x_train_k['min_date_new']).dt.days
x_train_k=x_train_k.drop(['average_time_diff', 'min_time_diff', 'max_time_diff', 'max_date_new','min_date_new'], axis=1)

# %%
x_test_k=x_test.copy()

x_test_k['average_time_diff_num']=x_test_k['average_time_diff'] / pd.Timedelta(days=1)
x_test_k['min_time_diff_num']=x_test_k['min_time_diff'] / pd.Timedelta(days=1)
x_test_k['max_time_diff_num']=x_test_k['max_time_diff'] / pd.Timedelta(days=1)
x_test_k['days']=(x_test_k['max_date_new']-x_test_k['min_date_new']).dt.days
x_test_k=x_test_k.drop(['average_time_diff', 'min_time_diff', 'max_time_diff', 'max_date_new','min_date_new'], axis=1)

# %%
x_train_k=x_train_k.fillna(0)
x_test_k=x_test_k.fillna(0)

# %%
# кластеризация
kmeans = KMeans(n_clusters=2)
kmeans.fit(x_train_k)
cluster_labels = kmeans.labels_

#  добавляем кластерные признаки для catboost
x_train['cluster'] = kmeans.predict(x_train_k)
x_test['cluster'] = kmeans.predict(x_test_k)

# добавляем кластерные признаки 
x_train_k['cluster'] = kmeans.predict(x_train_k)
x_test_k['cluster'] = kmeans.predict(x_test_k)
# Out:
# C:\Users\frolo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
x_train['max_date_new']=pd.to_datetime(x_train['max_date_new'])
x_train['min_date_new']=pd.to_datetime(x_train['min_date_new'])
x_test['max_date_new']=pd.to_datetime(x_test['max_date_new'])
x_test['min_date_new']=pd.to_datetime(x_test['min_date_new'])

# %% [markdown]
# ### Модель LGBM

# %%
scorer = {"AUC": "roc_auc", "f1":'f1'}
lgbm = LGBMClassifier(class_weight='balanced')
param_grid_LGBM = {'learning_rate':[0.5, 0.1, 0.01],
                'num_leaves':[10, 15, 20],
                'max_depth': [20, 30, 60]
}
lgbm_grid_search = GridSearchCV(lgbm, 
                                param_grid_LGBM, 
                                cv=5, 
                                scoring=scorer, 
                                refit="AUC", 
                                n_jobs=-1)

# %%
lgbm_grid_search.fit(x_train_k, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 537, number of negative: 35158
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001472 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2560
# [LightGBM] [Info] Number of data points in the train set: 35695, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# GridSearchCV(cv=5, estimator=LGBMClassifier(class_weight='balanced'), n_jobs=-1,
#              param_grid={'learning_rate': [0.5, 0.1, 0.01],
#                          'max_depth': [20, 30, 60],
#                          'num_leaves': [10, 15, 20]},
#              refit='AUC', scoring={'AUC': 'roc_auc', 'f1': 'f1'})

# %%
# Best parameters
print("Best parameters found:", lgbm_grid_search.best_params_)

# Best AUC score
print("Best AUC score found:", lgbm_grid_search.best_score_)

# Best estimator
best_lgbm_model = lgbm_grid_search.best_estimator_
# Out:
# Best parameters found: {'learning_rate': 0.01, 'max_depth': 20, 'num_leaves': 10}
# Best AUC score found: 0.763221617113221

# %% [markdown]
# ### Обучение HistGradientBoostingClassifier

# %%
scorer = {"AUC": "roc_auc", "f1":'f1'}

model_hb = HistGradientBoostingClassifier(random_state=1234, class_weight='balanced')

param_grid_hb = {
    'learning_rate': [0.5],
    'max_iter': [100, 200],
    'max_depth': [20, 30, 60]
}


hb_grid_search = GridSearchCV(model_hb,
                              param_grid_hb,
                              cv=5,
                              scoring=scorer,
                              refit="AUC",
                              n_jobs=-1)

# %%
hb_grid_search.fit(x_train_k, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=HistGradientBoostingClassifier(class_weight='balanced',
#                                                       random_state=1234),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.5], 'max_depth': [20, 30, 60],
#                          'max_iter': [100, 200]},
#              refit='AUC', scoring={'AUC': 'roc_auc', 'f1': 'f1'})

# %%
# Best parameters
print("Best parameters found:", hb_grid_search.best_params_)

# Best AUC score
print("Best AUC score found:", hb_grid_search.best_score_)

# Best estimator
best_hb_model = hb_grid_search.best_estimator_
# Out:
# Best parameters found: {'learning_rate': 0.5, 'max_depth': 20, 'max_iter': 100}
# Best AUC score found: 0.6805701386184743

# %% [markdown]
# ### Обучение Catboost

# %%
# Make a scorer from the custom scoring function
scorer = {"AUC": "roc_auc", "f1":'f1'}

param_grid = {
    'depth': [5]
}
catboost = CatBoostClassifier()
grid_search = GridSearchCV(catboost, 
                           param_grid, 
                           cv=5, 
                           scoring=scorer,
                           n_jobs=-1,
                           refit='AUC',
                           return_train_score=True)

# %%
grid_search.fit(x_train_k, y_train)
# Out:
# Learning rate set to 0.047413
# 0:	learn: 0.5963053	total: 159ms	remaining: 2m 38s
# 1:	learn: 0.5164739	total: 173ms	remaining: 1m 26s
# 2:	learn: 0.4487426	total: 187ms	remaining: 1m 2s
# 3:	learn: 0.3883226	total: 202ms	remaining: 50.2s
# 4:	learn: 0.3381389	total: 217ms	remaining: 43.1s
# 5:	learn: 0.2980277	total: 231ms	remaining: 38.3s
# 6:	learn: 0.2636692	total: 245ms	remaining: 34.8s
# 7:	learn: 0.2362901	total: 258ms	remaining: 32s
# 8:	learn: 0.2114189	total: 271ms	remaining: 29.8s
# 9:	learn: 0.1906026	total: 284ms	remaining: 28.1s
# 10:	learn: 0.1730919	total: 298ms	remaining: 26.8s
# 11:	learn: 0.1590136	total: 311ms	remaining: 25.6s
# 12:	learn: 0.1469432	total: 323ms	remaining: 24.5s
# 13:	learn: 0.1365711	total: 335ms	remaining: 23.6s
# 14:	learn: 0.1278949	total: 348ms	remaining: 22.9s
# 15:	learn: 0.1201327	total: 361ms	remaining: 22.2s
# 16:	learn: 0.1132679	total: 374ms	remaining: 21.6s
# 17:	learn: 0.1077990	total: 387ms	remaining: 21.1s
# ...

# %%
# Best parameters
print("Best parameters found:", grid_search.best_params_)

# Best AUC score
print("Best AUC score found:", grid_search.best_score_)

# Best estimator
best_cat_model = grid_search.best_estimator_
# Out:
# Best parameters found: {'depth': 5}
# Best AUC score found: 0.7445600223056372

# %% [markdown]
# ### Обучение Random forest Classifier

# %%
scorer = {"AUC": "roc_auc", "f1":'f1'}

param_grid = {
    'max_depth':  [10,20,50],
    'random_state': [1234],
    'n_estimators':[20, 50, 100],
    
}
forest = RandomForestClassifier()
forest_grid_search = GridSearchCV(forest, 
                           param_grid, 
                           cv=5, 
                           scoring=scorer,
                           n_jobs=-1,
                           refit='AUC',
                           return_train_score=True)

# %%
forest_grid_search.fit(x_train_k, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [10, 20, 50],
#                          'n_estimators': [20, 50, 100],
#                          'random_state': [1234]},
#              refit='AUC', return_train_score=True,
#              scoring={'AUC': 'roc_auc', 'f1': 'f1'})

# %%
# Best parameters
print("Best parameters found:", forest_grid_search.best_params_)

# Best AUC score
print("Best AUC score found:", forest_grid_search.best_score_)

# Best estimator
best_forest_model = forest_grid_search.best_estimator_
# Out:
# Best parameters found: {'max_depth': 10, 'n_estimators': 100, 'random_state': 1234}
# Best AUC score found: 0.7512679812159259

# %% [markdown]
# ### Сравнение моделей

# %%
result = pd.DataFrame(
    [grid_search.best_score_, lgbm_grid_search.best_score_, hb_grid_search.best_score_, forest_grid_search.best_score_], 
    index=['Catboost', 'LGBM', 'HistGradientBoostingClassifier', 'RandomForest'], 
    columns=['AUC']
)

result
# Out:
#                                      AUC
# Catboost                        0.744560
# LGBM                            0.763222
# HistGradientBoostingClassifier  0.680570
# RandomForest                    0.751268

# %% [markdown]
# ### Обучение лучшей модели

# %%
LGBM_prediction = best_lgbm_model.predict(x_test_k)

LGBM_Prediction_Proba = best_lgbm_model.predict_proba(x_test_k)[:,1]
metric_test_LGBM = roc_auc_score(y_test, LGBM_Prediction_Proba)


print ("ROC-AUC LGBM:",  metric_test_LGBM)
# Out:
# ROC-AUC LGBM: 0.7371270779209753

# %%
# Получение важности признаков
LGBM_importance_catboost = best_lgbm_model.feature_importances_

# Получение названий признаков
feature_names = x_test_k.columns

# Создание словаря с парами (название признака, важность)
feature_importance_dict = dict(zip(feature_names, LGBM_importance_catboost))

# Сортировка словаря по значению важности
sorted_feature_importance = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True)

# Разделение на названия признаков и их важности
sorted_features, sorted_importance = zip(*sorted_feature_importance)

# Построение графика
plt.figure(figsize=(10, 6))
plt.barh(range(len(sorted_features)), sorted_importance, align='center')
plt.yticks(range(len(sorted_features)), sorted_features)
plt.xlabel('Важность признака')
plt.ylabel('Признак')
plt.title('Важность признаков в модели LGBM')
plt.show()

# %%
# сохраняем вероятности только для положительного исхода
LGBM_probs = LGBM_Prediction_Proba
# рассчитываем ROC AUC
LGBM_auc = roc_auc_score(y_test, LGBM_probs)
print('LGBM: ROC AUC=%.3f' % (LGBM_auc))
# рассчитываем roc-кривую
fpr, tpr, treshold = metrics.roc_curve(y_test, LGBM_probs)
roc_auc = auc(fpr, tpr)
# строим график

plt.figure(figsize = (10,10))
plt.plot(fpr, tpr, color='darkorange',
         label='ROC кривая (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--', label='RandomModel')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Пример ROC-кривой')
plt.legend(loc="lower right")
plt.show()
# Out:
# LGBM: ROC AUC=0.737

# %%
heatmap_1 = sns.heatmap((confusion_matrix(y_test, LGBM_prediction)), 
                            cmap="YlGnBu", 
                            annot=True, fmt='d')
    
heatmap_1.set_title("Catboost", fontdict={'fontsize':14})
heatmap_1.set_xlabel('Предсказания', fontsize=14)
heatmap_1.set_ylabel('Истинный класс', fontsize=14)
# Out:
# Text(50.722222222222214, 0.5, 'Истинный класс')

# %% [markdown]
# ### Выводы:
# На этапе обучения моделей:
# - проведена кластеризация с помощью модели k-means
# -  подготовлены признаки для моделей
# - обучены 4 модели, результаты на тренировочной выборке:
# Catboost	0.744560,
# LGBM	0.763222,
# HistGradientBoostingClassifier	0.680570,
# RandomForest	0.751268
#
# - Лучшая модель LGBM обучена на тестово выборке. Результат ROC AUC=0.737

# %% [markdown]
# # Общие Выводы:
#
# #### На этапе ознакомления с данными были проделаны следующие шаги:
#
# - загрузка данных
# - объединение данных в одну таблицу
# - изменение итпов данных
# - поверка на наличие дубликатов. Обнаруженные дубликаты мы не удаляли, считая, что это разные товары, приобретенные в одно время
#
# #### На этапе исследовательского анализа данных были сделаны следующие выводы:
#
# Общее кличество уникальных пользователей на сайтах: 47004
#
# Количество уникальных клиентов в marketplace: 17787
# Количество уникальных клиентов в gifts: 326
#
# Количество уникальных клиентов в apparel: 28891
#
# Среднее количесво товаров в одном чеке по всем магазинам - 7.4 Самое высокое значение в apparel - 9.2, затем gifts - 4.6, наименьшее в marketplace - 2.4.
#
# В данных есть выбросы, самое больше количество товаров в одном чеке в apparel - 216. Проверили эти данные вручную. В этом заказе очень низкая цена товаров - 70, 139 рублей. Можно предположить, что это оптовая закупка, не будем удалять эти выбросы, чтобы не искажать поведение пользователей.
#
# Самая высокая средняя стоимость 1 единицы товара в заказе в магазине marketplace - 27'918, значительно ниже у gifts - 14'468, самый низкий в apparel - 1'110. Средний чек по всем магазинам - 8'263.
#
# Средняя стоимость чека в apparel - 7'467, в gifts - 69'138, в marketplace - 56'216.
#
# У нас есть данные за одинаковый временной промежуток для всех магазинов длинной в год. Создали дополнительный признак с месяцем продажи и посмотрели, меняется ли поведение покупателей в течение года. Поведение клиентов во всех трех магазинах существенно отличается.В магазине marketplace пик продаж в феврале, минимум в августе. В gifts пик продаж в июне и июле, спад в апреле и декабре. В apparel пик в ноябре-декабре, падение в январе, феврале. Самые стабильные продажи в marketplace, наибольшие падения у apparel.
#
# #### На этапе отбора и генерации признаков было сделано  следующее:
#
# Добавлена целевая метрика
#
# Была применена агрегация по уникальным пользователям и созданы следующие синтетические признаки:
# - average_total_price	max_
# - total_price
# - min_total_price
# - max_date_new
# - min_date_new
# - average_quantity_count
# - average_price
# - max_price
# - min_price
# - average_time_diff
# - min_time_diff
# - max_time_diff
#
# #### На этапе обучения моделей:
# - проведена кластеризация с помощью модели k-means
# -  подготовлены признаки для моделей
# - обучены 4 модели, результаты на тренировочной выборке:
# Catboost	0.744560,
# LGBM	0.763222,
# HistGradientBoostingClassifier	0.680570,
# RandomForest	0.751268
#
# - Лучшая модель LGBM обучена на тестово выборке. Результат ROC AUC=0.737
